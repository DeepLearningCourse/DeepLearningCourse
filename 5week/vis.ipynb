# %% [markdown]
# # word2vec visualization
# using modified vis.py from https://github.com/nishio/mycorpus

# %%
import visword2vec
vis = visword2vec.visWord2Vec("vectors.bin")
vis_phrase = visword2vec.visWord2Vec("vectors-phrase.bin")
# Out:
# loading
# loaded
# loading
# loaded

# %%
vis.plot('king')
vis_phrase.plot('king')
# Out:
# [ 0.13118866  0.10623945]
# [ 0.16855377  0.12011987]

# %%
vis.plot('queen')
vis_phrase.plot('queen')
# Out:
# [ 0.16200846  0.11511865]
# [ 0.12542991  0.11516068]
